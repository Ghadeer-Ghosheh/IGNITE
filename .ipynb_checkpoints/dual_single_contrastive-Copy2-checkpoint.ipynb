# %%
import numpy as np
import tensorflow.compat.v1 as tf
tf.compat.v1.disable_v2_behavior()
import os
import pickle
import pandas as pd
import matplotlib.pyplot as plt
import random
import os
from networks import observed_only_vae,IMM_vae

from utils import ones_target, zeros_target
import numpy as np
from dual_1_contrastive_new import IGNITE
import timeit
start = timeit.default_timer()
from bottleneck import push
# Out:
# WARNING:tensorflow:From C:\Users\gghos\anaconda3\envs\tf\lib\site-packages\tensorflow\python\compat\v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
gpus = tf.config.list_physical_devices('GPU')
if gpus:
  try:
    # Currently, memory growth needs to be the same across GPUs
    for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)
    logical_gpus = tf.config.list_logical_devices('GPU')
    print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
  except RuntimeError as e:
    # Memory growth must be set before GPUs have been initialized
    print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %%
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %%
ls
# Out:
#  Volume in drive C is Windows-SSD
#  Volume Serial Number is 9462-7CBF
#
#  Directory of C:\Users\gghos\OneDrive\Desktop\IGNITE
#
# 04/10/2022  09:41 AM    <DIR>          .
# 04/10/2022  09:35 AM    <DIR>          ..
# 04/10/2022  10:26 AM    <DIR>          code
# 04/10/2022  09:41 AM    <DIR>          data
# 04/10/2022  09:38 AM    <DIR>          final-physionet
# 04/10/2022  09:41 AM    <DIR>          logs
# 04/10/2022  09:35 AM               100 README.md
#                1 File(s)            100 bytes
#                6 Dir(s)  846,808,317,952 bytes free

# %% [markdown]
# Load datasets

# %%
data_path = 'final-physio/datasets/'
with open(os.path.join(data_path, 'FP_2012_mask.pkl'), 'rb') as f:
    miss = pickle.load(f)
# with open(os.path.join(data_path, 'P2012_age_conditions.pkl'), 'rb') as f:
#     statics_label = pickle.load(f)
with open(os.path.join(data_path, 'FP_2012_LOCF.pkl'), 'rb') as f:
    LVCF = pickle.load(f)
with open(os.path.join(data_path, 'FP_2012_zero.pkl'), 'rb') as f:
    zero = pickle.load(f)
with open(os.path.join(data_path, 'FP_2012_Intervention.pkl'), 'rb') as f:
    interventions = pickle.load(f)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_29680\3911224883.py in <module>
#       1 data_path = 'final-physio/datasets/'
# ----> 2 with open(os.path.join(data_path, 'FP_2012_mask.pkl'), 'rb') as f:
#       3     miss = pickle.load(f)
#       4 # with open(os.path.join(data_path, 'P2012_age_conditions.pkl'), 'rb') as f:
#       5 #     statics_label = pickle.load(f)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'final-physio/datasets/FP_2012_mask.pkl'

# %%
with open(os.path.join(data_path, 'FP_2012_origional.pkl'), 'rb') as f:
    origional = pickle.load(f)
LOCF_na_=np.where(np.isnan(push(origional, axis = 1)), -100, push(origional, axis = 1))

# %%
with open(os.path.join('/person.pkl'), 'rb') as f:
    mask_personalized = pickle.load(f)

# %% [markdown]
# pass data

# %%
sample_size= len(LVCF)
statics_label = np.asarray(interventions)[:sample_size]
discrete_x = np.multiply(LVCF[:sample_size],mask_personalized[:sample_size])
continuous_x = zero[:sample_size]
miss_sample_x = miss[:sample_size]

# %%
batch_size = 400
time_steps = continuous_x.shape[1]
num_pre_epochs = 200

shared_latent_dim = 10
z_size = shared_latent_dim
ts_feat= continuous_x.shape[2]
conditional = True
num_labels = 1

# %%
statics_label=np.where(np.isnan(statics_label), 0, statics_label)

# %%
# networks for continuousVAE
observed_only_vae = observed_only_vae(batch_size=batch_size, time_steps=time_steps, oo_vae_dim=ts_feat, z_dim=z_size,
                  conditional=conditional, num_labels=num_labels)

IMM_vae = IMM_vae(batch_size=batch_size, time_steps=time_steps, imm_vae_dim=ts_feat, z_dim=z_size,
                  conditional=conditional, num_labels=num_labels)


# create data directory for saving
checkpoint_dir = os.path.join("MyDrive/physionet.org/", "data/checkpoint/")
if not os.path.exists(checkpoint_dir):
    os.makedirs(checkpoint_dir)

# %%
exp_name = "IGNITE_dual_single_contrastive_400_treat_dot_IMM_35_001_001_0.8_discriminator"

# %%
tf.compat.v1.reset_default_graph()
run_config = tf.compat.v1.ConfigProto()
with tf.compat.v1.Session(config = run_config) as sess:
        model = full_model(sess=sess,
                      batch_size=batch_size,
                      time_steps=time_steps,
                      num_pre_epochs=num_pre_epochs,
                      checkpoint_dir=checkpoint_dir,
                      oo_vae_dim=ts_feat, 
                      c_z_size=z_size, c_data_sample=continuous_x,
                      observedonlyvae=ObservedOnlyvae, 
                      imm_vae_dim=ts_feat, 
                      d_z_size=z_size, d_data_sample=discrete_x,
                      IMM_vae=IMM_vae,
=                      mask_data_sample=miss_sample_x,experiment_name=exp_name,
                      conditional=conditional, 
                       num_labels=num_labels,
                      statics_label=statics_label)
        model.build()
        model.train()

stop = timeit.default_timer()
print('Time: ', stop - start)
# Out:
# WARNING:tensorflow:`tf.nn.rnn_cell.MultiRNNCell` is deprecated. This class is equivalent as `tf.keras.layers.StackedRNNCells`, and will be replaced by that in Tensorflow 2.0.
# WARNING:tensorflow:`tf.nn.rnn_cell.MultiRNNCell` is deprecated. This class is equivalent as `tf.keras.layers.StackedRNNCells`, and will be replaced by that in Tensorflow 2.0.
# WARNING:tensorflow:From C:\Users\gghos\anaconda3\envs\tf\lib\site-packages\keras\layers\rnn\legacy_cells.py:1048: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# (400, 48, 36)
# WARNING:tensorflow:`tf.nn.rnn_cell.MultiRNNCell` is deprecated. This class is equivalent as `tf.keras.layers.StackedRNNCells`, and will be replaced by that in Tensorflow 2.0.
# WARNING:tensorflow:`tf.nn.rnn_cell.MultiRNNCell` is deprecated. This class is equivalent as `tf.keras.layers.StackedRNNCells`, and will be replaced by that in Tensorflow 2.0.
# WARNING:tensorflow:`tf.nn.rnn_cell.MultiRNNCell` is deprecated. This class is equivalent as `tf.keras.layers.StackedRNNCells`, and will be replaced by that in Tensorflow 2.0.
# WARNING:tensorflow:From C:\Users\gghos\Downloads\IGNITE\ehrMGAN\networks.py:336: static_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell, unroll=True)`, which is equivalent to this API
# WARNING:tensorflow:`tf.nn.rnn_cell.MultiRNNCell` is deprecated. This class is equivalent as `tf.keras.layers.StackedRNNCells`, and will be replaced by that in Tensorflow 2.0.
# finalize
# data_size 4000
# start training
# VAE epoch 0
# 10
# VAE epoch 1
# 10
# VAE epoch 2
# 10
# VAE epoch 3
# 10
# VAE epoch 4
# 10
# VAE epoch 5
# 10
# VAE epoch 6
# 10
# VAE epoch 7
# 10
# VAE epoch 8
# 10
# VAE epoch 9
# 10
# VAE epoch 10
# 10
# VAE epoch 11
# 10
# VAE epoch 12
# 10
# VAE epoch 13
# 10
# VAE epoch 14
# 10
# VAE epoch 15
# 10
# VAE epoch 16
# 10
# VAE epoch 17
# 10
# VAE epoch 18
# 10
# VAE epoch 19
# 10
# VAE epoch 20
# 10
# VAE epoch 21
# 10
# VAE epoch 22
# 10
# VAE epoch 23
# 10
# VAE epoch 24
# 10
# VAE epoch 25
# 10
# VAE epoch 26
# 10
# VAE epoch 27
# 10
# VAE epoch 28
# 10
# VAE epoch 29
# 10
# VAE epoch 30
# 10
# VAE epoch 31
# 10
# VAE epoch 32
# 10
# VAE epoch 33
# 10
# VAE epoch 34
# 10
# VAE epoch 35
# 10
# VAE epoch 36
# 10
# VAE epoch 37
# 10
# VAE epoch 38
# 10
# VAE epoch 39
# 10
# VAE epoch 40
# 10
# VAE epoch 41
# 10
# VAE epoch 42
# 10
# VAE epoch 43
# 10
# VAE epoch 44
# 10
# VAE epoch 45
# 10
# VAE epoch 46
# 10
# VAE epoch 47
# 10
# VAE epoch 48
# 10
# VAE epoch 49
# 10
# VAE epoch 50
# 10
# VAE epoch 51
# 10
# VAE epoch 52
# 10
# VAE epoch 53
# 10
# VAE epoch 54
# 10
# VAE epoch 55
# 10
# VAE epoch 56
# 10
# VAE epoch 57
# 10
# VAE epoch 58
# 10
# VAE epoch 59
# 10
# VAE epoch 60
# 10
# VAE epoch 61
# 10
# VAE epoch 62
# 10
# VAE epoch 63
# 10
# VAE epoch 64
# 10
# VAE epoch 65
# 10
# VAE epoch 66
# 10
# VAE epoch 67
# 10
# VAE epoch 68
# 10
# VAE epoch 69
# 10
# VAE epoch 70
# 10
# VAE epoch 71
# 10
# VAE epoch 72
# 10
# VAE epoch 73
# 10
# VAE epoch 74
# 10
# VAE epoch 75
# 10
# VAE epoch 76
# 10
# VAE epoch 77
# 10
# VAE epoch 78
# 10
# VAE epoch 79
# 10
# VAE epoch 80
# 10
# VAE epoch 81
# 10
# VAE epoch 82
# 10
# VAE epoch 83
# 10
# VAE epoch 84
# 10
# VAE epoch 85
# 10
# VAE epoch 86
# 10
# VAE epoch 87
# 10
# VAE epoch 88
# 10
# VAE epoch 89
# 10
# VAE epoch 90
# 10
# VAE epoch 91
# 10
# VAE epoch 92
# 10
# VAE epoch 93
# 10
# VAE epoch 94
# 10
# VAE epoch 95
# 10
# VAE epoch 96
# 10
# VAE epoch 97
# 10
# VAE epoch 98
# 10
# VAE epoch 99
# 10
# VAE epoch 100
# 10
# VAE epoch 101
# 10
# VAE epoch 102
# 10
# VAE epoch 103
# 10
# VAE epoch 104
# 10
# VAE epoch 105
# 10
# VAE epoch 106
# 10
# VAE epoch 107
# 10
# VAE epoch 108
# 10
# VAE epoch 109
# 10
# VAE epoch 110
# 10
# VAE epoch 111
# 10
# VAE epoch 112
# 10
# VAE epoch 113
# 10
# VAE epoch 114
# 10
# VAE epoch 115
# 10
# VAE epoch 116
# 10
# VAE epoch 117
# 10
# VAE epoch 118
# 10
# VAE epoch 119
# 10
# VAE epoch 120
# 10
# VAE epoch 121
# 10
# VAE epoch 122
# 10
# VAE epoch 123
# 10
# VAE epoch 124
# 10
# VAE epoch 125
# 10
# VAE epoch 126
# 10
# VAE epoch 127
# 10
# VAE epoch 128
# 10
# VAE epoch 129
# 10
# VAE epoch 130
# 10
# VAE epoch 131
# 10
# VAE epoch 132
# 10
# VAE epoch 133
# 10
# VAE epoch 134
# 10
# VAE epoch 135
# 10
# VAE epoch 136
# 10
# VAE epoch 137
# 10
# VAE epoch 138
# 10
# VAE epoch 139
# 10
# VAE epoch 140
# 10
# VAE epoch 141
# 10
# VAE epoch 142
# 10
# VAE epoch 143
# 10
# VAE epoch 144
# 10
# VAE epoch 145
# 10
# VAE epoch 146
# 10
# VAE epoch 147
# 10
# VAE epoch 148
# 10
# VAE epoch 149
# 10
# VAE epoch 150
# 10
# VAE epoch 151
# 10
# VAE epoch 152
# 10
# VAE epoch 153
# 10
# VAE epoch 154
# 10
# VAE epoch 155
# 10
# VAE epoch 156
# 10
# VAE epoch 157
# 10
# VAE epoch 158
# 10
# VAE epoch 159
# 10
# VAE epoch 160
# 10
# VAE epoch 161
# 10
# VAE epoch 162
# 10
# VAE epoch 163
# 10
# VAE epoch 164
# 10
# VAE epoch 165
# 10
# VAE epoch 166
# 10
# VAE epoch 167
# 10
# VAE epoch 168
# 10
# VAE epoch 169
# 10
# VAE epoch 170
# 10
# VAE epoch 171
# 10
# VAE epoch 172
# 10
# VAE epoch 173
# 10
# VAE epoch 174
# 10
# VAE epoch 175
# 10
# VAE epoch 176
# 10
# VAE epoch 177
# 10
# VAE epoch 178
# 10
# VAE epoch 179
# 10
# VAE epoch 180
# 10
# VAE epoch 181
# 10
# VAE epoch 182
# 10
# VAE epoch 183
# 10
# VAE epoch 184
# 10
# VAE epoch 185
# 10
# VAE epoch 186
# 10
# VAE epoch 187
# 10
# VAE epoch 188
# 10
# VAE epoch 189
# 10
# VAE epoch 190
# 10
# VAE epoch 191
# 10
# VAE epoch 192
# 10
# VAE epoch 193
# 10
# VAE epoch 194
# 10
# VAE epoch 195
# 10
# VAE epoch 196
# 10
# VAE epoch 197
# 10
# VAE epoch 198
# 10
# VAE epoch 199
# 10
# finished model training
# Time:  2645.1435414000002

# %%
# %reload_ext tensorboard
# %tensorboard --logdir logs/last
# Out:
# Reusing TensorBoard on port 6006 (pid 17372), started 2:08:18 ago. (Use '!kill 17372' to kill it.)
#       <iframe id="tensorboard-frame-c4b292c08363dfd6" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-c4b292c08363dfd6");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>
